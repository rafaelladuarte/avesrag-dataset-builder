# %%
import pandas as pd
import re

# %%
def tem_caracter_chines(texto):
    # Regex para caracteres chineses (CJK Unified Ideographs)
    padrao = r'[\u4e00-\u9fff]'
    return bool(re.search(padrao, texto))

# %%
path = 'data/treat/dedup2_result_scraper_wikiaves_udi.json'
df = pd.read_json(path)
df
# Out:
#                        taxonomia          ordem     familia  subfamilia  \
# 0                 Rhea americana     Rheiformes     Rheidae        None
# 1         Crypturellus undulatus   Tinamiformes   Tinamidae        None
# 2      Crypturellus parvirostris   Tinamiformes   Tinamidae        None
# 3           Rhynchotus rufescens   Tinamiformes   Tinamidae        None
# 4               Nothura maculosa   Tinamiformes   Tinamidae        None
# ..                           ...            ...         ...         ...
# 365  Schistochlamys ruficapillus  Passeriformes  Thraupidae  Thraupinae
# 366          Paroaria dominicana  Passeriformes  Thraupidae  Thraupinae
# 367              Thraupis sayaca  Passeriformes  Thraupidae  Thraupinae
# 368            Thraupis palmarum  Passeriformes  Thraupidae  Thraupinae
# 369              Stilpnia cayana  Passeriformes  Thraupidae  Thraupinae
#
#              genero       especie              nome_pt  \
# 0              Rhea     americana                  ema
# 1      Crypturellus     undulatus                  jaó
# 2      Crypturellus  parvirostris      inhambu-chororó
# 3        Rhynchotus     rufescens               perdiz
# 4           Nothura      maculosa      codorna-amarela
# ..              ...           ...                  ...
# 365  Schistochlamys  ruficapillus       bico-de-veludo
# 366        Paroaria    dominicana  cardeal-do-nordeste
# 367        Thraupis        sayaca     sanhaço-cinzento
# 368        Thraupis      palmarum  sanhaço-do-coqueiro
# 369        Stilpnia        cayana        saíra-amarela
#
#                    nome_eng  \
# 0              Greater Rhea
# 1         Undulated Tinamou
# 2      Small-billed Tinamou
# 3        Red-winged Tinamou
# 4           Spotted Nothura
# ..                      ...
# 365        Cinnamon Tanager
# 366     Red-cowled Cardinal
# 367          Sayaca Tanager
# 368            Palm Tanager
# 369  Burnished-buff Tanager
#
#                                           url_wikiaves  \
# 0                 https://www.wikiaves.com.br/wiki/ema
# 1                 https://www.wikiaves.com.br/wiki/jao
# 2     https://www.wikiaves.com.br/wiki/inhambu-chororo
# 3              https://www.wikiaves.com.br/wiki/perdiz
# 4     https://www.wikiaves.com.br/wiki/codorna-amarela
# ..                                                 ...
# 365    https://www.wikiaves.com.br/wiki/bico-de-veludo
# 366  https://www.wikiaves.com.br/wiki/cardeal-do-no...
# 367  https://www.wikiaves.com.br/wiki/sanhaco-cinzento
# 368  https://www.wikiaves.com.br/wiki/sanhaco-do-co...
# 369     https://www.wikiaves.com.br/wiki/saira-amarela
#
#                                        caracteristicas  ...  \
# 0    134 – 170 cm de altura dependendo da postura a...  ...
# 1                  Mede cerca de 31 cm de comprimento.  ...
# 2    Muito semelhante ao inhambu-chintã, possui o c...  ...
# 3    Mede entre 38 e 42 centímetros de comprimento....  ...
# 4    Tem cerca de 23 centímetros e pesa aproximadam...  ...
# ..                                                 ...  ...
# 365  Mede cerca de 18 centímetros de comprimento e ...  ...
# 366  Mede cerca de 17,2 centímetros. Plumagem de ca...  ...
# 367  Mede entre 16 e 19 centímetros de comprimento ...  ...
# 368  Mede entre 17 e 18 centímetros de comprimento ...  ...
# 369  O macho possui uma plumagem de coloração amare...  ...
#
#                                        dieta_principal  \
# 0    [folhas, frutas, sementes, insetos, moluscos, ...
# 1                          [frutas, moluscos, insetos]
# 2                          [sementes, insetos, vermes]
# 3    [insetos, sementes, raízes, tubérculos, roedores]
# 4                [grãos, artrópodes, moluscos, frutas]
# ..                                                 ...
# 365                [frutos, sementes, flores, insetos]
# 366                                 [sementes, frutas]
# 367                       [frutas, sementes, insectos]
# 368                          [insetos, néctar, frutos]
# 369                                  [insetos, frutos]
#
#                                                habitat  locomocao  \
# 0                      [campo natural, cerrado, pampa]  corredora
# 1                               [mata ciliar, cerrado]       None
# 2        [cerrado, campo natural, plantação, pastagem]       None
# 3                   [campo natural, cerrado, caatinga]  corredora
# 4              [campo natural, plantação, área urbana]    voadora
# ..                                                 ...        ...
# 365    [cerrado, caatinga, campo natural, área urbana]
# 366                                [caatinga, cerrado]    voadora
# 367  [mata ciliar, zona de cultivo, mato aberto, ár...    voadora
# 368      [área urbana, floresta aberta, campo natural]    voadora
# 369  [mata ciliar, caATINGa, campo natural, plantaç...    voadora
#
#     sociabilidade              atividade    tipo_bico       bico  \
# 0        gregária  [diurna, crepuscular]  generalista        NaN
# 1            None               [diurna]  generalista        NaN
# 2            None  [diurna, crepuscular]     sondador        NaN
# 3       solitária               [diurna]     sondador        NaN
# 4        gregária               [diurna]         None        NaN
# ..            ...                    ...          ...        ...
# 365   territorial                     []         None  Frugívoro
# 366          None               [diurna]  generalista        NaN
# 367      gregária               [diurna]  generalista        NaN
# 368      gregária               [diurna]  generalista        NaN
# 369      gregária               [diurna]         None  Frugívoro
#
#                                        asa          pata       tipo
# 0                                      NaN           NaN        NaN
# 1                                      NaN           NaN        NaN
# 2                                      NaN           NaN        NaN
# 3                                      NaN           NaN        NaN
# 4                                      NaN           NaN        NaN
# ..                                     ...           ...        ...
# 365                                                         onívoro
# 366                                    NaN           NaN        NaN
# 367                                    NaN           NaN        NaN
# 368                                    NaN           NaN        NaN
# 369  Alto coeficiente de proporcionalidade  Anizodáctilo  frugívoro
#
# [370 rows x 31 columns]

# %%
df['contem_chines'] = df['resumo_llm'].apply(tem_caracter_chines)
df[df['contem_chines'] == True]["resumo_llm"]
# Out:
# Series([], Name: resumo_llm, dtype: object)

# %%
df["tamanho"].unique()
# Out:
# array(['grande', 'media', None, 'pequena', ''], dtype=object)

# %%
df.loc[df["tamanho"]=='Grande','tamanho'] = 'grande'
df.loc[df["tamanho"]=='Médio','tamanho'] = 'media'
df.loc[df["tamanho"]=='médio','tamanho'] = 'media'
df.loc[df["tamanho"]=='Pequeno','tamanho'] = 'pequena'
df.loc[df["tamanho"]=='pequeno','tamanho'] = 'pequena'

# %%
df["tipo_bico"].unique()
# Out:
# array(['generalista', 'sondador', None, 'filtrador', 'frugivoro',
#        'granivoro', 'insetivoro', 'nectarivoro', 'insetos em troncos',
#        'limicola', 'pescador', 'carniceiro', 'raptorial'], dtype=object)

# %%
new_df = df[[
    'taxonomia', 'ordem', 'familia', 'genero', 'especie',
    'nome_pt', 'nome_eng', 'url_wikiaves', 'url_image', 'resumo_llm',
    'tamanho', 'tipo_bico', 'cores', 'habitat','dieta_principal',
    'atividade'
]]
new_df
# Out:
#                        taxonomia          ordem     familia          genero  \
# 0                 Rhea americana     Rheiformes     Rheidae            Rhea
# 1         Crypturellus undulatus   Tinamiformes   Tinamidae    Crypturellus
# 2      Crypturellus parvirostris   Tinamiformes   Tinamidae    Crypturellus
# 3           Rhynchotus rufescens   Tinamiformes   Tinamidae      Rhynchotus
# 4               Nothura maculosa   Tinamiformes   Tinamidae         Nothura
# ..                           ...            ...         ...             ...
# 365  Schistochlamys ruficapillus  Passeriformes  Thraupidae  Schistochlamys
# 366          Paroaria dominicana  Passeriformes  Thraupidae        Paroaria
# 367              Thraupis sayaca  Passeriformes  Thraupidae        Thraupis
# 368            Thraupis palmarum  Passeriformes  Thraupidae        Thraupis
# 369              Stilpnia cayana  Passeriformes  Thraupidae        Stilpnia
#
#           especie              nome_pt                nome_eng  \
# 0       americana                  ema            Greater Rhea
# 1       undulatus                  jaó       Undulated Tinamou
# 2    parvirostris      inhambu-chororó    Small-billed Tinamou
# 3       rufescens               perdiz      Red-winged Tinamou
# 4        maculosa      codorna-amarela         Spotted Nothura
# ..            ...                  ...                     ...
# 365  ruficapillus       bico-de-veludo        Cinnamon Tanager
# 366    dominicana  cardeal-do-nordeste     Red-cowled Cardinal
# 367        sayaca     sanhaço-cinzento          Sayaca Tanager
# 368      palmarum  sanhaço-do-coqueiro            Palm Tanager
# 369        cayana        saíra-amarela  Burnished-buff Tanager
#
#                                           url_wikiaves  \
# 0                 https://www.wikiaves.com.br/wiki/ema
# 1                 https://www.wikiaves.com.br/wiki/jao
# 2     https://www.wikiaves.com.br/wiki/inhambu-chororo
# 3              https://www.wikiaves.com.br/wiki/perdiz
# 4     https://www.wikiaves.com.br/wiki/codorna-amarela
# ..                                                 ...
# 365    https://www.wikiaves.com.br/wiki/bico-de-veludo
# 366  https://www.wikiaves.com.br/wiki/cardeal-do-no...
# 367  https://www.wikiaves.com.br/wiki/sanhaco-cinzento
# 368  https://www.wikiaves.com.br/wiki/sanhaco-do-co...
# 369     https://www.wikiaves.com.br/wiki/saira-amarela
#
#                                              url_image  \
# 0    https://s3.amazonaws.com/media.wikiaves.com.br...
# 1    https://s3.amazonaws.com/media.wikiaves.com.br...
# 2    https://s3.amazonaws.com/media.wikiaves.com.br...
# 3    https://s3.amazonaws.com/media.wikiaves.com.br...
# 4    https://s3.amazonaws.com/media.wikiaves.com.br...
# ..                                                 ...
# 365  https://s3.amazonaws.com/media.wikiaves.com.br...
# 366  https://s3.amazonaws.com/media.wikiaves.com.br...
# 367  https://s3.amazonaws.com/media.wikiaves.com.br...
# 368  https://s3.amazonaws.com/media.wikiaves.com.br...
# 369  https://s3.amazonaws.com/media.wikiaves.com.br...
#
#                                             resumo_llm  tamanho    tipo_bico  \
# 0    A ema (Rhea americana) é uma ave ratita, a mai...   grande  generalista
# 1    A espécie Crypturellus undulatus, conhecida co...    media  generalista
# 2    Crypturellus parvirostris, conhecido como inha...     None     sondador
# 3    Rhynchotus rufescens, uma ave terrícola da fam...    media     sondador
# 4    A espécie *Nothura maculosa* é uma ave de pequ...  pequena         None
# ..                                                 ...      ...          ...
# 365  A espécie Schistochlamys ruficapillus, também ...  pequena         None
# 366  A Paroaria dominicana, com uma comprimento de ...    media  generalista
# 367  A Thraupis sayaca, também conhecida como sayac...  pequena  generalista
# 368  A Thraupis palmarum, conhecida como sanhaço-do...    media  generalista
# 369  A espécie *Stilpnia cayana* é uma ave que apre...    media         None
#
#                                                  cores  \
# 0                            [cinza, preto, amarelado]
# 1                                                   []
# 2                    [marrom avermelhado, acinzentado]
# 3    [preto, bege, marrom escuro, canela, castanho ...
# 4                           [marrons, amarelo, branco]
# ..                                                 ...
# 365  [azul-acinzentada, negra, acanelado, branco-ac...
# 366            [vermelho, cinza, preto, branco, pardo]
# 367         [cinza, azul turquesa, esverdeado, branco]
# 368                            [esverdeada, amarelada]
# 369           [amarelo-dourada, amarelo, preto, negra]
#
#                                                habitat  \
# 0                      [campo natural, cerrado, pampa]
# 1                               [mata ciliar, cerrado]
# 2        [cerrado, campo natural, plantação, pastagem]
# 3                   [campo natural, cerrado, caatinga]
# 4              [campo natural, plantação, área urbana]
# ..                                                 ...
# 365    [cerrado, caatinga, campo natural, área urbana]
# 366                                [caatinga, cerrado]
# 367  [mata ciliar, zona de cultivo, mato aberto, ár...
# 368      [área urbana, floresta aberta, campo natural]
# 369  [mata ciliar, caATINGa, campo natural, plantaç...
#
#                                        dieta_principal              atividade
# 0    [folhas, frutas, sementes, insetos, moluscos, ...  [diurna, crepuscular]
# 1                          [frutas, moluscos, insetos]               [diurna]
# 2                          [sementes, insetos, vermes]  [diurna, crepuscular]
# 3    [insetos, sementes, raízes, tubérculos, roedores]               [diurna]
# 4                [grãos, artrópodes, moluscos, frutas]               [diurna]
# ..                                                 ...                    ...
# 365                [frutos, sementes, flores, insetos]                     []
# 366                                 [sementes, frutas]               [diurna]
# 367                       [frutas, sementes, insectos]               [diurna]
# 368                          [insetos, néctar, frutos]               [diurna]
# 369                                  [insetos, frutos]               [diurna]
#
# [370 rows x 16 columns]

# %%
path = "data/treat/wikiaves_species_by_registro.csv"
df_registro = pd.read_csv(path)
df_registro
# Out:
# Empty DataFrame
# Columns: [Nome da Espécie, Sons, Fotos]
# Index: []

# %%
new_df = new_df.merge(
    df_registro[['Nome da Espécie',"Fotos"]],
    left_on='nome_pt',right_on="Nome da Espécie", how='left')
new_df
# Out:
#                        taxonomia          ordem     familia          genero  \
# 0                 Rhea americana     Rheiformes     Rheidae            Rhea
# 1         Crypturellus undulatus   Tinamiformes   Tinamidae    Crypturellus
# 2      Crypturellus parvirostris   Tinamiformes   Tinamidae    Crypturellus
# 3           Rhynchotus rufescens   Tinamiformes   Tinamidae      Rhynchotus
# 4               Nothura maculosa   Tinamiformes   Tinamidae         Nothura
# ..                           ...            ...         ...             ...
# 365  Schistochlamys ruficapillus  Passeriformes  Thraupidae  Schistochlamys
# 366          Paroaria dominicana  Passeriformes  Thraupidae        Paroaria
# 367              Thraupis sayaca  Passeriformes  Thraupidae        Thraupis
# 368            Thraupis palmarum  Passeriformes  Thraupidae        Thraupis
# 369              Stilpnia cayana  Passeriformes  Thraupidae        Stilpnia
#
#           especie              nome_pt                nome_eng  \
# 0       americana                  ema            Greater Rhea
# 1       undulatus                  jaó       Undulated Tinamou
# 2    parvirostris      inhambu-chororó    Small-billed Tinamou
# 3       rufescens               perdiz      Red-winged Tinamou
# 4        maculosa      codorna-amarela         Spotted Nothura
# ..            ...                  ...                     ...
# 365  ruficapillus       bico-de-veludo        Cinnamon Tanager
# 366    dominicana  cardeal-do-nordeste     Red-cowled Cardinal
# 367        sayaca     sanhaço-cinzento          Sayaca Tanager
# 368      palmarum  sanhaço-do-coqueiro            Palm Tanager
# 369        cayana        saíra-amarela  Burnished-buff Tanager
#
#                                           url_wikiaves  \
# 0                 https://www.wikiaves.com.br/wiki/ema
# 1                 https://www.wikiaves.com.br/wiki/jao
# 2     https://www.wikiaves.com.br/wiki/inhambu-chororo
# 3              https://www.wikiaves.com.br/wiki/perdiz
# 4     https://www.wikiaves.com.br/wiki/codorna-amarela
# ..                                                 ...
# 365    https://www.wikiaves.com.br/wiki/bico-de-veludo
# 366  https://www.wikiaves.com.br/wiki/cardeal-do-no...
# 367  https://www.wikiaves.com.br/wiki/sanhaco-cinzento
# 368  https://www.wikiaves.com.br/wiki/sanhaco-do-co...
# 369     https://www.wikiaves.com.br/wiki/saira-amarela
#
#                                              url_image  \
# 0    https://s3.amazonaws.com/media.wikiaves.com.br...
# 1    https://s3.amazonaws.com/media.wikiaves.com.br...
# 2    https://s3.amazonaws.com/media.wikiaves.com.br...
# 3    https://s3.amazonaws.com/media.wikiaves.com.br...
# 4    https://s3.amazonaws.com/media.wikiaves.com.br...
# ..                                                 ...
# 365  https://s3.amazonaws.com/media.wikiaves.com.br...
# 366  https://s3.amazonaws.com/media.wikiaves.com.br...
# 367  https://s3.amazonaws.com/media.wikiaves.com.br...
# 368  https://s3.amazonaws.com/media.wikiaves.com.br...
# 369  https://s3.amazonaws.com/media.wikiaves.com.br...
#
#                                             resumo_llm  tamanho    tipo_bico  \
# 0    A ema (Rhea americana) é uma ave ratita, a mai...   grande  generalista
# 1    A espécie Crypturellus undulatus, conhecida co...    media  generalista
# 2    Crypturellus parvirostris, conhecido como inha...     None     sondador
# 3    Rhynchotus rufescens, uma ave terrícola da fam...    media     sondador
# 4    A espécie *Nothura maculosa* é uma ave de pequ...  pequena         None
# ..                                                 ...      ...          ...
# 365  A espécie Schistochlamys ruficapillus, também ...  pequena         None
# 366  A Paroaria dominicana, com uma comprimento de ...    media  generalista
# 367  A Thraupis sayaca, também conhecida como sayac...  pequena  generalista
# 368  A Thraupis palmarum, conhecida como sanhaço-do...    media  generalista
# 369  A espécie *Stilpnia cayana* é uma ave que apre...    media         None
#
#                                                  cores  \
# 0                            [cinza, preto, amarelado]
# 1                                                   []
# 2                    [marrom avermelhado, acinzentado]
# 3    [preto, bege, marrom escuro, canela, castanho ...
# 4                           [marrons, amarelo, branco]
# ..                                                 ...
# 365  [azul-acinzentada, negra, acanelado, branco-ac...
# 366            [vermelho, cinza, preto, branco, pardo]
# 367         [cinza, azul turquesa, esverdeado, branco]
# 368                            [esverdeada, amarelada]
# 369           [amarelo-dourada, amarelo, preto, negra]
#
#                                                habitat  \
# 0                      [campo natural, cerrado, pampa]
# 1                               [mata ciliar, cerrado]
# 2        [cerrado, campo natural, plantação, pastagem]
# 3                   [campo natural, cerrado, caatinga]
# 4              [campo natural, plantação, área urbana]
# ..                                                 ...
# 365    [cerrado, caatinga, campo natural, área urbana]
# 366                                [caatinga, cerrado]
# 367  [mata ciliar, zona de cultivo, mato aberto, ár...
# 368      [área urbana, floresta aberta, campo natural]
# 369  [mata ciliar, caATINGa, campo natural, plantaç...
#
#                                        dieta_principal              atividade  \
# 0    [folhas, frutas, sementes, insetos, moluscos, ...  [diurna, crepuscular]
# 1                          [frutas, moluscos, insetos]               [diurna]
# 2                          [sementes, insetos, vermes]  [diurna, crepuscular]
# 3    [insetos, sementes, raízes, tubérculos, roedores]               [diurna]
# 4                [grãos, artrópodes, moluscos, frutas]               [diurna]
# ..                                                 ...                    ...
# 365                [frutos, sementes, flores, insetos]                     []
# 366                                 [sementes, frutas]               [diurna]
# 367                       [frutas, sementes, insectos]               [diurna]
# 368                          [insetos, néctar, frutos]               [diurna]
# 369                                  [insetos, frutos]               [diurna]
#
#     Nome da Espécie_x  Fotos_x Nome da Espécie_y  Fotos_y
# 0                 ema     21.0               ema     21.0
# 1                 jaó      2.0               jaó      2.0
# 2     inhambu-chororó      5.0   inhambu-chororó      5.0
# 3              perdiz      2.0            perdiz      2.0
# 4     codorna-amarela      2.0   codorna-amarela      2.0
# ..                ...      ...               ...      ...
# 365               NaN      NaN               NaN      NaN
# 366               NaN      NaN               NaN      NaN
# 367               NaN      NaN               NaN      NaN
# 368               NaN      NaN               NaN      NaN
# 369               NaN      NaN               NaN      NaN
#
# [370 rows x 20 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   taxonomia        370 non-null    object
#  1   ordem            370 non-null    object
#  2   familia          370 non-null    object
#  3   genero           370 non-null    object
#  4   especie          370 non-null    object
#  5   nome_pt          370 non-null    object
#  6   nome_eng         370 non-null    object
#  7   url_wikiaves     370 non-null    object
#  8   url_image        369 non-null    object
#  9   resumo_llm       370 non-null    object
#  10  tamanho          352 non-null    object
#  11  tipo_bico        275 non-null    object
#  12  cores            370 non-null    object
#  13  habitat          369 non-null    object
#  14  dieta_principal  369 non-null    object
#  15  atividade        370 non-null    object
#  16  Nome da Espécie  24 non-null     object
#  17  Fotos            24 non-null     float64
# dtypes: float64(1), object(17)
# memory usage: 52.2+ KB

# %%
print(df_registro.columns)
print(new_df.columns)
# Out:
# Index(['Nome da Espécie', 'Sons', 'Fotos'], dtype='object')
# Index(['taxonomia', 'ordem', 'familia', 'genero', 'especie', 'nome_pt',
#        'nome_eng', 'url_wikiaves', 'url_image', 'resumo_llm', 'tamanho',
#        'tipo_bico', 'cores', 'habitat', 'dieta_principal', 'atividade'],
#       dtype='object')

# %%
new_df.to_json("oficial_dataset_udi.json", orient="records")
