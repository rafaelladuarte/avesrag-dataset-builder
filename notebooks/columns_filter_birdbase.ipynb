# %%
import pandas as pd

# %%
path_birdbase =  "/home/elladarte/Documentos/my_github/avesrag-dataset-builder/data/raw/BIRDBASEv2025.1.xlsx"

# %%
df_birdbase = pd.read_excel(
    path_birdbase,sheet_name="Data",skiprows=1
)
df_birdbase
# Out:
#        IOC 15.1 English Name (BirdLife > IOC > Clements>AviList)  \
# 0             1                                   Common Ostrich
# 1             6                                   Somali Ostrich
# 2             8                                     Greater Rhea
# 3            14                                      Lesser Rhea
# 4            18                              Southern Brown Kiwi
# ...         ...                                              ...
# 11584     37962                            White-bellied Tanager
# 11585     37964                                 Paradise Tanager
# 11586     37969                             Opal-crowned Tanager
# 11587     37970                              Opal-rumped Tanager
# 11588     37974                          Silver-breasted Tanager
#
#       Latin (BirdLife > IOC > Clements>AviList)  \
# 0                              Struthio camelus
# 1                        Struthio molybdophanes
# ...

# %%
df_birdbase.columns
# Out:
# Index(['IOC 15.1', 'English Name (BirdLife > IOC > Clements>AviList)',
#        'Latin (BirdLife > IOC > Clements>AviList)',
#        'HBW/BirdLife International (v9.1)', 'IOC World Bird List (v15.1)',
#        'eBird/Clements (V2024b)', 'AviList v1 2025', 'Order',
#        'Family IOC 15.1', 'Family Clements v2024b',
#        'Family HBW/BirdLife v9.1 (2024)', 'Family AviList v1 2025', 'Genus',
#        'Species', 'Source', '2024 IUCN Red List category', 'RR', 'ISL', 'RLM',
#        'LAT', 'Female MinMass', 'Female MaxMass', 'Male MinMass',
#        'Male MaxMass', 'Unsexed MinMass', 'Unsexed MaxMass', 'Average Mass',
#        'Xmin', 'NormMin', 'Elevational Range', 'NormMax', 'Xmax', 'F', 'BM',
#        'WD', 'SH', 'SV', 'G', 'PL', 'R', 'D', 'A', 'RV', 'C', 'W', 'SE', 'O',
#        'O- DESC', 'Primary Habitat', 'HB', 'Primary Diet', 'IN-Wt', 'FR-Wt',
#        'NE-Wt', 'SE-Wt', 'VE-Wt', 'FI-Wt', 'SC-Wt', 'PL-Wt', 'MS-Wt', 'SUM-Wt',
# ...

# %%
df_birdbase_base = df_birdbase[
    [
        "eBird/Clements (V2024b)",
        "Species",
        "2024 IUCN Red List category",
        "ISL",  # Restrita a ilha
        "RLM",  # Região Globo
        "LAT",  # Distribuição Latitudinal
        "Average Mass",  # Média de peso

        # Habitats
        "F",   # Floresta
        "BM",  # Bambuzais
        "WD",  # Florestas secas e savânicas
        "SH",  # Arbustais e formações abertas com vegetação secundária
        "SV",  # Savanas e campos arborizados
        "G",   # Campos e gramíneas de altitude
        "PL",  # Planícies e áreas semiáridas abertas
        "R",   # Áreas rochosas, serras e afloramentos
        "D",   # Desertos verdadeiros
        "A",   # Ambientes artificiais e antrópicos
        "C",   # Ambientes costeiros
        "RV",  # Ambientes ripários e florestas de galeria
        "W",   # Áreas úmidas interiores
        "SE",  # Mar aberto/pelágico
        "O",   # Outros
        "Primary Habitat",  # Habitat principal

        # Dietas
        "Primary Diet",  # Dieta principal
        "IN-Wt",  # Insetívora / Invertebrívora
        "FR-Wt",  # Frugívora
        "NE-Wt",  # Nectarívora
        "SE-Wt",  # Granívora / Sementívora
        "VE-Wt",  # Carnívora (vertebrados terrestres)
        "FI-Wt",  # Piscívora
        "SC-Wt",  # Necrófaga / Oportunista
        "PL-Wt",  # Herbívora (não reprodutiva)
        "MS-Wt",  # Miscelânea / Ovivora

        # Comportamento social
        "Social_1",  # Colonial
        "Social_2",  # Social
        "Social_3",  # Pares e grupos familiares
        "Social_4",  # Individualmente e pares
        "Social_5",  # Solitário
        "Social_6",  # Lekking

        # Sistema reprodutivo
        "Mono",  # Monogâmica
        "Poly",  # Poligâmica

        "Nest_Type", # Tipo de ninho
        "Nest_SBS", # Substrato do ninho

        #  Movimento
        "Mig",    # Migratória
        "Alt",    # Migração altitudinal
        "Irreg",  # Nômade
        "Disp",   # Dispersão de longa distância
        "Sed",    # Sedentária
    ]
]

df_birdbase_base
# Out:
#       eBird/Clements (V2024b)        Species 2024 IUCN Red List category  ISL  \
# 0            Struthio camelus        camelus                          LC    0
# 1      Struthio molybdophanes  molybdophanes                          VU    0
# 2              Rhea americana      americana                          NT    0
# 3                Rhea pennata        pennata                          LC    0
# 4           Apteryx australis      australis                          VU    1
# ...                       ...            ...                         ...  ...
# 11584    Tangara brasiliensis   brasiliensis                          LC    0
# 11585       Tangara chilensis      chilensis                          LC    0
# 11586      Tangara callophrys     callophrys                          LC    0
# 11587           Tangara velia          velia                          LC    0
# 11588                     NaN     cyanomelas                          LC    0
#
# ...
